# %% [markdown]
# <a href="https://colab.research.google.com/github/canetinha1/Tipos_dados_py_3f/blob/main/rev_tipos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#revisão de variaveis e tipos de dados
#tipos básicos

#int: números inteiros (sem casas decimais)
idade = 17

#float: ponto flutuante (com casas decimais)
altura = 1.80

#string: (ou str) texto puro
nome = "Isaque Felipe Torres"

#bool: booleano (sim, nao, verdade, mentira, true, false)
estudante = True

#tipos de coleção
#lista coleção ordenada
frutas = ["maça", "banana", "laranja", "manga"]

#tupla, geralmente usada para guardar coordenadas
cianorte = (-23.6631, -52.6054)

#set (conjunto de dados não repetitivos)
numeros = {1,2,3,4,5}

#dic (dicionario)
pessoa = {"nome": "Isaque", "idade":17}

#none type, quando preciso que algo
#"seja realmente nulo"
valor = None
